# %% [markdown]
# # My First Project
# - Sample Python code

# %%
# A simple program to greet the user
name = input("Please enter your name: ")
print(f"Greetings, {name}! Welcome to my first GitHub project.")
